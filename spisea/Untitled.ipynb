# %%
import hoki
hoki.dummy_dict
# Out:
# {'timestep': 0,
#  'age': 1,
#  'log(R1)': 2,
#  'log(T1)': 3,
#  'log(L1)': 4,
#  'M1': 5,
#  'He_core1': 6,
#  'CO_core1': 7,
#  'ONe_core1': 8,
#  'X': 10,
#  'Y': 11,
#  'C': 14,
#  'N': 15,
#  'O': 16,
#  'Ne': 17,
#  'MH1': 18,
#  'MHe1': 19,
#  'MC1': 20,
#  'MN1': 21,
#  'MO1': 22,
#  'MNe1': 23,
#  'MMg1': 24,
#  'MSi1': 25,
#  'MFe1': 26,
#  'envelope_binding_E': 27,
#  'star_binding_E': 28,
#  'Mrem_weakSN': 29,
#  'Mej_weakSN': 30,
#  'Mrem_SN': 31,
#  'Mej_SN': 32,
#  'AM_bin': 33,
#  'P_bin': 34,
#  'log(a)': 35,
#  'M2': 37,
#  'MTOT': 38,
#  'DM1W': 39,
#  'DM2W': 40,
#  'DM1A': 41,
#  'DM2A': 42,
#  'DM1R': 43,
#  'DM2R': 44,
#  'DAM': 45,
#  'log(R2)': 46,
#  'log(T2)': 47,
#  'log(L2)': 48,
#  '?': 49,
#  'modelimf': 50,
#  'mixedimf': 51,
#  'V-I': 52,
#  'U': 53,
#  'B': 54,
#  'V': 55,
#  'R': 56,
#  'I': 57,
#  'J': 58,
#  'H': 59,
#  'K': 60,
#  'u': 61,
#  'g': 62,
#  'r': 63,
#  'i': 64,
#  'z': 65,
#  'f300w': 66,
#  'f336w': 67,
#  'f435w': 68,
# ...
