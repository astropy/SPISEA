# %% [markdown]
# ## Testing the BPASS cluster at 10^7 years age.
# Here, I try to create a 10000 solar mass BPASS cluster and ResolvedCluster. **This is to demonstrate the issue I have with the mass-matching inside of the Binary_Cluster implementation.**

# %%
import spisea
from spisea import evolution, synthetic
import math
# Check if the evolution class works fine
import time
import numpy as np
t1=time.time()
bps=evolution.BPASS()
iso1=synthetic.Isochrone_Binary(7.0, 0.7, 100,math.log10(1), mass_sampling=1, filepath='/g/lu/scratch/ryotainagaki/BPASS_iso_filesTimedIsolated/')
# Out:
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/pysynphot/locations.py:346: UserWarning: Extinction files not found in /g/lu/models/cdbs/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/pysynphot/refs.py:125: UserWarning: No thermal tables found, no thermal calculations can be performed. No files found for /g/lu/models/cdbs/mtab/*_tmt.fits
#   'no thermal calculations can be performed. ' + str(e))
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/units/quantity.py:477: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /u/ryotainagaki/Desktop/PyPopStar/spisea/evolution.py:1771: RuntimeWarning: overflow encountered in power
#   (1 / cs.au) * un.m)
# ...

# %%
iso1.primaries[np.where(iso1.primaries['mass']< 0)]
# Out:
# <Table length=0>
#   mass     L      Teff     R      logg  ... m_ubv_V m_ubv_B m_ubv_R m_ubv_I
# solMass    W       K       m            ...
# float64 float64 float64 float64 float64 ... float64 float64 float64 float64
# ------- ------- ------- ------- ------- ... ------- ------- ------- -------

# %%
iso1.secondaries[np.where(iso1.secondaries['mass'] < 0)]
# Out:
# <Table length=0>
#   mass   log_a     L      Teff     R    ... m_ubv_V m_ubv_B m_ubv_R m_ubv_I
# solMass            W       K       m    ...
# float64 float64 float64 float64 float64 ... float64 float64 float64 float64
# ------- ------- ------- ------- ------- ... ------- ------- ------- -------

# %%
iso1.secondaries[np.where(iso1.singles['mass'] < 0)]
# Out:
# <Table length=0>
#   mass   log_a     L      Teff     R    ... m_ubv_V m_ubv_B m_ubv_R m_ubv_I
# solMass            W       K       m    ...
# float64 float64 float64 float64 float64 ... float64 float64 float64 float64
# ------- ------- ------- ------- ------- ... ------- ------- ------- -------

# %% [markdown]
# For a sanity check, we can see that the primaries, secondaries, and single stars have phasees of 5 or of 101. Note that we will have a phase of 110 in order to indicate a mystery compact remnant that BPASS provides for NEWSECMODS (secondary star models with compact primaries). This is since we haven't added neutron stars or black holes yet. Stars with phase of -99 exist, and those are the secondary stars that have already merged.

# %%
iso2=synthetic.IsochronePhot(7.0, 0.7, 100, math.log10(1), mass_sampling =1 , recomp=True) # New MIST v.1 isochrone for same metallicity
# Out:
# Changing to logg=3.50 for T= 26068 logg=3.41
# Changing to logg=3.50 for T= 26167 logg=3.41
# Changing to logg=3.50 for T= 26263 logg=3.42
# Changing to logg=3.50 for T= 26355 logg=3.42
# Changing to logg=3.50 for T= 26443 logg=3.42
# Changing to logg=3.50 for T= 26528 logg=3.43
# Changing to logg=3.50 for T= 26609 logg=3.43
# Changing to logg=3.50 for T= 26685 logg=3.43
# Changing to logg=3.50 for T= 26758 logg=3.43
# Changing to logg=3.50 for T= 26826 logg=3.44
# Changing to logg=3.50 for T= 26889 logg=3.44
# Changing to logg=3.50 for T= 26943 logg=3.44
# Changing to logg=3.50 for T= 26985 logg=3.44
# Changing to logg=3.50 for T= 27008 logg=3.45
# Changing to logg=3.50 for T= 27006 logg=3.45
# Changing to logg=3.50 for T= 26955 logg=3.45
# Changing to logg=3.50 for T= 26861 logg=3.44
# Changing to logg=3.50 for T= 26740 logg=3.44
# Changing to logg=3.50 for T= 26600 logg=3.44
# Changing to logg=3.50 for T= 26446 logg=3.43
# Changing to logg=3.50 for T= 26289 logg=3.42
# ...

# %%
from spisea import imf
from spisea.imf import imf, multiplicity
from spisea import ifmr

# %% [markdown]
# Make the clusters corresponding to the binary star isochrone and the MISTv.1 isochrone

# %%
clus_1=synthetic.Binary_Cluster(iso1, imf.Kennicutt_1983(multiplicity=multiplicity.MultiplicityResolvedDK()), 10000, ifmr=ifmr.IFMR_Spera15())
clus_2=synthetic.ResolvedCluster(iso2, imf.Kennicutt_1983(multiplicity=multiplicity.MultiplicityResolvedDK()), 10000, ifmr=ifmr.IFMR_Spera15())
# Out:
# 1632.8446500000075
# /opt/anaconda3/envs/astroconda/lib/python3.7/site-packages/astropy/table/column.py:1020: RuntimeWarning: invalid value encountered in greater_equal
#   result = getattr(super(), op)(other)
# Found 783 stars out of mass range
# Found 98 companions out of stellar mass range

# %%
from scipy.spatial import cKDTree as KDTree
primary_mass = 0.6108086242692268
secondary_mass = 0.30536360066412166
loga=-0.534758928598925
iso = iso1

# %%
kd = KDTree(np.transpose(np.array([iso.primaries['mass']/primary_mass, iso.secondaries['mass']/secondary_mass, iso.secondaries['log_a']/loga])))

# %%
q_results = kd.query(np.array([[1, 1, 1]]))

# %%
q_results
# Out:
# (array([0.99322867]), array([1114]))

# %%
iso1.primaries[3602]
# Out:
# <Row index=3602>
#   mass            L                  Teff               R                logg         isWR mass_current  phase  source      m_ubv_U           m_ubv_V            m_ubv_B            m_ubv_R           m_ubv_I
# solMass           W                   K                 m                                    solMass
# float64        float64             float64           float64           float64        bool   float64    float64 int64       float64           float64            float64            float64           float64
# ------- --------------------- ----------------- ----------------- ------------------ ----- ------------ ------- ------ ----------------- ------------------ ------------------ ----------------- -----------------
#    12.0 6.010933580065605e+30 25081.29752520464 4617003079.503744 3.8693695271134714 False     11.93004     5.0      1 11.80273948902653 12.176137129710247 12.738272547165757 9.680392111544691 6.383288155499987

# %%
iso1.secondaries[3602]
# Out:
# <Row index=3602>
#        mass             log_a                  L                  Teff               R                 logg        isWR mass_current  phase  merged source      m_ubv_U            m_ubv_V            m_ubv_B            m_ubv_R            m_ubv_I
#      solMass                                   W                   K                 m                                    solMass
#      float64           float64              float64             float64           float64            float64       bool   float64    float64  bool  int64       float64            float64            float64            float64            float64
# ----------------- ------------------ --------------------- ----------------- ------------------ ----------------- ----- ------------ ------- ------ ------ ------------------ ------------------ ------------------ ------------------ -----------------
# ...

# %% [markdown]
# Let's make sure that I am getting just about enough star mass for my cluster. (It was a bug before I used an adjustment factor.)

# %%
clus_1.star_systems['systemMass'].sum()
# Out:
# 2707.809855972534

# %%
arr =[]
for x in range(100):
    clus_1=synthetic.Binary_Cluster(iso1, imf.Kennicutt_1983(multiplicity=multiplicity.MultiplicityResolvedDK()), 10000, ifmr=ifmr.IFMR_Spera15())
    arr.append(clus_1.star_systems['systemMass'].sum())
# Out:
# 1455.0567900000049
# 1492.443580000006
# 1243.7935800000027
# 1323.6600000000003
# 1480.640370000003
# 1209.7167900000006
# 1339.0878600000033
# 1500.0057200000035
# 1430.4378600000018
# 1332.3157200000014
# 1485.720000000003
# 1408.8035800000034
# 1337.8403700000008
# 1435.0335800000048
# 1729.6989300000062
# 1449.877860000004
# 1379.4957200000038
# 1772.5978600000062
# 1084.2620799999993
# 1467.9507100000021
# 1678.0646500000053
# 561.3222099999996
# 1439.8767900000048
# 1539.6735800000083
# 1280.8012100000017
# 1364.9646500000022
# 1569.7467900000054
# 1545.0657200000026
# 1586.064650000006
# 1121.60893
# 1323.7867900000026
# 1267.6689300000035
# 1405.6335800000004
# 1501.5657200000053
# 1431.0178600000033
# 1153.8157200000014
# 1399.1935800000033
# 1559.0278600000056
# 1197.9457200000013
# 1321.5578600000022
# 1353.5267900000067
# 1681.5189300000025
# 1425.6967900000016
# 1707.876790000006
# 1411.7789300000015
# 1529.1090000000029
# 1348.284650000003
# 1533.4546500000054
# ...

# %%
import matplotlib.pyplot as plt
hist, bins, patch = plt.hist(np.array(arr), bins=30, histtype='step', label='BPASS clusters with x mass')
plt.title("BPASS cluster mass distribution (# of models within mass bin over mass)")
print(np.median(np.array(arr)))
plt.xlabel("Initial total mass of the cluster in solar masses")
plt.ylabel("# of times cluster of that mass was generated")
plt.legend()
# Out:
# 1810.3413312633459

# %%
clus_1.companions['mass']
# Out:
# <Column name='mass' dtype='float64' length=555>
#                 0.3
#                0.24
# 0.27999999999999997
#                 4.0
# 0.27999999999999997
# 0.27999999999999997
#                0.12
#                0.42
#                0.42
#                0.42
#                 0.4
#                 0.4
#                 ...
#                0.42
# 0.27999999999999997
#                0.35
#                0.42
#  0.5599999999999999
#                 0.3
#                0.24
#                 0.4
#                 0.4
#                 0.3
#                 3.2
#                0.12

# %%
import matplotlib.pyplot as plt
plt.hist(iso1.primaries['mass'], bins=30)
plt.yscale('log')

# %%
import matplotlib.pyplot as plt
plt.hist(iso1.secondaries['mass'], bins=30)
plt.yscale('log')

# %%
import matplotlib.pyplot as plt
plt.hist(iso1.singles['mass'], bins=30)
plt.yscale('log')

# %%
import matplotlib.pyplot as plt
plt.hist(clus_1.star_systems['systemMass'], bins=30)
plt.yscale('log')

# %%
import matplotlib.pyplot as plt
plt.hist(clus_2.star_systems['systemMass'], bins=30)
plt.yscale('log')

# %%
hist, bins, patch = plt.hist(clus_1.star_systems['systemMass'], bins=30, histtype='step', label='BPASS')
plt.hist(clus_2.star_systems['systemMass'], bins=bins, histtype='step', label='MISTv.1')
plt.xlabel("initial mass in solar masses")
plt.label("mass distribution plots of the companions on logarithmic scale of the horizontal axis.")
plt.yscale('log')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-7a266d7c8c36> in <module>
#       2 plt.hist(clus_2.star_systems['systemMass'], bins=bins, histtype='step', label='MISTv.1')
#       3 plt.xlabel("initial mass in solar masses")
# ----> 4 plt.label("mass distribution plots of the companions on logarithmic scale of the horizontal axis.")
#       5 plt.yscale('log')
#       6 plt.legend()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'label'

# %%
hist, bins, patch = plt.hist(clus_1.star_systems['systemMass'], bins=30, histtype='step', label='BPASS')
plt.hist(clus_2.star_systems['systemMass'], bins=bins, histtype='step', label='MISTv.1')
plt.xlabel("initial mass in solar masses")
plt.label("mass distribution plots of the companions on logarithmic scale of the horizontal axis.")
plt.yscale('log')
plt.legend()

# %%
hist, bins, patch = plt.hist(clus_1.star_systems['mass'], bins=30, histtype='step', label='BPASS')
plt.hist(clus_2.star_systems['mass'], bins=bins, histtype='step', label='MISTv.1')
plt.xlabel("initial mass in solar masses")
plt.label("mass distribution plots of the companions on logarithmic scale of the horizontal axis.")
plt.yscale('log')
plt.legend()

# %%
hist, bins, patch = plt.hist(clus_1.companions['mass'], bins=30, histtype='step', label='BPASS')
plt.hist(clus_2.companions['mass'], bins=30, histtype='step', label='MISTv.1')
plt.xlabel("initial mass in solar masses")
plt.label("mass distribution plots of the companions on logarithmic scale of the horizontal axis.")
plt.yscale('log')
plt.legend()

# %%
# Comparison with the MIST v1 cluster
clus_2.star_systems['systemMass'].sum()

# %%
import matplotlib.pyplot as plt
plt.hist(iso1.primaries['mass'], bins=30)
plt.yscale('log')
plt.xlabel("initial mass in solar masses")
plt.label("mass distribution plots of the primaries on logarithmic scale of the horizontal axis.")

# %%
import matplotlib.pyplot as plt
plt.hist(iso1.singles['mass'], bins=30)
plt.yscale('log')
plt.xlabel("initial mass in solar masses")
plt.label("mass distribution plots of the primaries on logarithmic scale of the horizontal axis.")

# %%
import matplotlib.pyplot as plt
plt.hist(iso1.secondaries['mass'], bins=30)
plt.yscale('log')
plt.xlabel("initial mass in solar masses")
plt.label("mass distribution plots of the primaries on logarithmic scale of the horizontal axis.")

# %%
import numpy as np
np.where(iso1.secondaries['mass']>iso1.primaries['mass'])

# %%
np.unique(iso1.primaries[np.where(iso1.secondaries['mass']>iso1.primaries['mass'])]['source'])

# %%
clus_2.star_systems['systemMass'].sum()

# %%
hist, bins, patch = plt.hist(clus_1.companions['log_a'], bins=30, histtype='step', label='BPASS')
plt.hist(clus_2.companions['log_a'], bins=30, histtype='step', label='MISTv.1')
plt.legend()
