# %% [markdown]
# ## Below is the code to re-create Figure 3
#
# ### Topic: CMD in different filters at different metallicities

# %%
# Import necessary packages. 
from popstar import synthetic, evolution, atmospheres, reddening, ifmr
from popstar.imf import imf, multiplicity
import numpy as np
import pylab as py
import pdb
import os
import pylab as py
# Out:
# /Users/mwhosek/anaconda3/envs/astroconda/lib/python3.5/site-packages/pysynphot/locations.py:329: UserWarning: Extinction files not found in /Users/mwhosek/models/models_2019_07/cdbs/extinction
#   warnings.warn('Extinction files not found in %s' % (extdir, ))

# %%
# Generate sets isochrones with the same parameters, only one isochrone is solar while
# the other is SMC metallicity ([Z] = - 0.65). Do this for two ages, one younger
# population and another old population
# Parameters: 
# AKs = 0.5 mag, dist = 4000 pc, redlaw = Cardelli+89, 
# evolution models = MIST, atmospheres = get_merged_atmospheres, 

# Define isochrone parameters
logAge_young = 7.0 # Age in log(years)
logAge_old = 9.0 # Age in log(years)
AKs = 0.5 # Ks filter extinction in mags
dist = 4000 # distance in parsecs
metal_sol = 0 # metallicity in [M/H]
metal_smc = -0.65 # metallicity in [M/H]
atm_func = atmospheres.get_merged_atmosphere
evo = evolution.MISTv1()
redlaw = reddening.RedLawCardelli(3.1) # Rv = 3.1

# Select a wide range of filters to explore
filt_list = ['ubv,V', 'ubv,I', 'nirc2,J', 'nirc2,Kp', 'jwst,F070W',
             'wfc3,ir,f153m', 'jwst,F277W', 'jwst,F480M']


# Using same iso_dir as figure 2 
iso_dir = 'iso_mist_r1/'

if not os.path.exists(iso_dir):
    os.mdkir(iso_dir)

# %%
# Now to actually make the isochrone objects. Eliminate white dwarfs
# from the isochrone, since we only want to consider stars for now
# Young Pops
iso_sol_young = synthetic.IsochronePhot(logAge_young, AKs, dist, metallicity=metal_sol,
                                 evo_model=evo, atm_func=atm_func,
                                  filters=filt_list, red_law=redlaw,
                                 iso_dir=iso_dir, mass_sampling=2)
iso_sol_young = iso_sol_young.points

iso_smc_young = synthetic.IsochronePhot(logAge_young, AKs, dist, metallicity=metal_smc,
                                 evo_model=evo, atm_func=atm_func,
                                  filters=filt_list, red_law=redlaw,
                                 iso_dir=iso_dir, mass_sampling=2)
iso_smc_young = iso_smc_young.points

# Old pops
iso_sol_old = synthetic.IsochronePhot(logAge_old, AKs, dist, metallicity=metal_sol,
                                 evo_model=evo, atm_func=atm_func,
                                  filters=filt_list, red_law=redlaw,
                                 iso_dir=iso_dir, mass_sampling=2)
good = np.where(iso_sol_old.points['phase'] < 100)
iso_sol_old = iso_sol_old.points[good]

iso_smc_old = synthetic.IsochronePhot(logAge_old, AKs, dist, metallicity=metal_smc,
                                 evo_model=evo, atm_func=atm_func,
                                  filters=filt_list, red_law=redlaw,
                                 iso_dir=iso_dir, mass_sampling=2)
good = np.where(iso_smc_old.points['phase'] < 100)
iso_smc_old = iso_smc_old.points[good]
# Out:
# Changing to logg=3.50 for T= 26167 logg=3.41
# Changing to logg=3.50 for T= 26355 logg=3.42
# Changing to logg=3.50 for T= 26528 logg=3.43
# Changing to logg=3.50 for T= 26685 logg=3.43
# Changing to logg=3.50 for T= 26826 logg=3.44
# Changing to logg=3.50 for T= 26943 logg=3.44
# Changing to logg=3.50 for T= 27008 logg=3.45
# Changing to logg=3.50 for T= 26955 logg=3.45
# Changing to logg=3.50 for T= 26740 logg=3.44
# Changing to logg=3.50 for T= 26446 logg=3.43
# Changing to logg=3.50 for T= 26128 logg=3.41
# Changing to logg=3.00 for T= 20939 logg=2.98
# Changing to logg=3.00 for T= 20655 logg=2.96
# Changing to logg=3.00 for T= 20372 logg=2.93
# Changing to logg=3.00 for T= 20091 logg=2.91
# Changing to logg=3.00 for T= 19813 logg=2.88
# Changing to logg=3.00 for T= 19538 logg=2.86
# Changing to logg=3.00 for T= 19265 logg=2.83
# Changing to logg=2.50 for T= 15781 logg=2.48
# Changing to logg=2.50 for T= 15554 logg=2.46
# Changing to logg=2.50 for T= 15330 logg=2.43
# Changing to logg=2.50 for T= 15109 logg=2.40
# Changing to logg=2.50 for T= 14891 logg=2.38
# Changing to logg=2.50 for T= 14675 logg=2.35
# Changing to logg=2.50 for T= 14463 logg=2.33
# Changing to logg=2.50 for T= 14254 logg=2.30
# Changing to logg=2.50 for T= 14048 logg=2.27
# Changing to logg=2.50 for T= 13844 logg=2.25
# Changing to logg=2.50 for T= 13644 logg=2.22
# Changing to logg=2.50 for T= 13447 logg=2.19
# Changing to logg=2.50 for T= 13253 logg=2.17
# Changing to logg=2.50 for T= 13061 logg=2.14
# Changing to logg=2.50 for T= 12873 logg=2.12
# Changing to logg=2.50 for T= 12687 logg=2.09
# Changing to logg=2.50 for T= 12504 logg=2.06
# Changing to logg=2.50 for T= 12323 logg=2.04
# Changing to logg=2.50 for T= 12145 logg=2.01
# Changing to logg=2.50 for T= 11970 logg=1.98
# Changing to logg=2.50 for T= 11798 logg=1.96
# Changing to logg=2.00 for T= 11628 logg=1.93
# Changing to logg=2.00 for T= 11460 logg=1.90
# Changing to logg=2.00 for T= 11295 logg=1.88
# Changing to logg=2.00 for T= 11132 logg=1.85
# Changing to logg=2.00 for T= 10972 logg=1.82
# Changing to logg=2.00 for T= 10814 logg=1.80
# Changing to logg=2.00 for T= 10658 logg=1.77
# Changing to logg=2.00 for T= 10505 logg=1.74
# Changing to logg=2.00 for T= 10354 logg=1.72
# Changing to logg=2.00 for T= 10206 logg=1.69
# Changing to logg=2.00 for T= 10059 logg=1.67
# Changing to logg=2.00 for T=  9915 logg=1.64
# Changing to logg=2.00 for T=  9773 logg=1.61
# Changing to logg=2.00 for T=  9634 logg=1.59
# Changing to logg=2.00 for T=  9496 logg=1.56
# Changing to logg=2.00 for T=  9225 logg=1.51
# Changing to logg=1.50 for T=  8963 logg=1.46
# Changing to logg=1.50 for T=  8711 logg=1.41
# Changing to logg=1.50 for T=  8468 logg=1.36
# Isochrone generation took 41.879600 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.50  dist = 4000
#      Starting at:  2019-11-06 14:31:26.825149   Usually takes ~5 minutes
# Starting filter: ubv,V   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.112 Msun  T =  3025 K  m_ubv_V = 29.78
# M =   9.793 Msun  T = 24007 K  m_ubv_V = 14.98
# M =  17.889 Msun  T = 15781 K  m_ubv_V = 11.07
# Starting filter: ubv,I   Elapsed time: 6.40 seconds
# Starting synthetic photometry
# M =   0.112 Msun  T =  3025 K  m_ubv_I = 23.73
# M =   9.793 Msun  T = 24007 K  m_ubv_I = 13.24
# M =  17.889 Msun  T = 15781 K  m_ubv_I = 9.18
# Starting filter: nirc2,J   Elapsed time: 12.42 seconds
# Starting synthetic photometry
# M =   0.112 Msun  T =  3025 K  m_nirc2_J = 21.56
# M =   9.793 Msun  T = 24007 K  m_nirc2_J = 12.43
# M =  17.889 Msun  T = 15781 K  m_nirc2_J = 8.30
# Starting filter: nirc2,Kp   Elapsed time: 16.89 seconds
# Starting synthetic photometry
# M =   0.112 Msun  T =  3025 K  m_nirc2_Kp = 20.14
# M =   9.793 Msun  T = 24007 K  m_nirc2_Kp = 11.90
# M =  17.889 Msun  T = 15781 K  m_nirc2_Kp = 7.70
# Starting filter: jwst,F070W   Elapsed time: 22.75 seconds
# Starting synthetic photometry
# M =   0.112 Msun  T =  3025 K  m_jwst_F070W = 26.37
# M =   9.793 Msun  T = 24007 K  m_jwst_F070W = 14.01
# M =  17.889 Msun  T = 15781 K  m_jwst_F070W = 10.02
# Starting filter: wfc3,ir,f153m   Elapsed time: 30.46 seconds
# Starting synthetic photometry
# M =   0.112 Msun  T =  3025 K  m_hst_f153m = 20.89
# M =   9.793 Msun  T = 24007 K  m_hst_f153m = 12.13
# M =  17.889 Msun  T = 15781 K  m_hst_f153m = 7.98
# Starting filter: jwst,F277W   Elapsed time: 37.76 seconds
# Starting synthetic photometry
# M =   0.112 Msun  T =  3025 K  m_jwst_F277W = 20.01
# M =   9.793 Msun  T = 24007 K  m_jwst_F277W = 11.77
# M =  17.889 Msun  T = 15781 K  m_jwst_F277W = 7.54
# Starting filter: jwst,F480M   Elapsed time: 46.34 seconds
# Starting synthetic photometry
# M =   0.112 Msun  T =  3025 K  m_jwst_F480M = 19.47
# M =   9.793 Msun  T = 24007 K  m_jwst_F480M = 11.80
# M =  17.889 Msun  T = 15781 K  m_jwst_F480M = 7.54
#       Time taken: 54.05 seconds
# WARNING: VerifyWarning: Keyword name 'METAL_ACT' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# Changing to logg=3.50 for T= 26853 logg=3.50
# Changing to logg=3.50 for T= 26651 logg=3.47
# Changing to logg=3.50 for T= 26510 logg=3.45
# Changing to logg=3.50 for T= 26585 logg=3.44
# Changing to logg=3.50 for T= 26804 logg=3.45
# Changing to logg=3.50 for T= 27052 logg=3.46
# Changing to logg=3.50 for T= 27309 logg=3.47
# Changing to logg=3.50 for T= 27567 logg=3.48
# Changing to logg=3.50 for T= 27819 logg=3.49
# Changing to logg=3.50 for T= 28005 logg=3.49
# Changing to logg=3.50 for T= 27744 logg=3.47
# Changing to logg=3.50 for T= 27502 logg=3.45
# Changing to logg=3.50 for T= 27259 logg=3.42
# Changing to logg=3.50 for T= 27015 logg=3.40
# Changing to logg=3.50 for T= 26775 logg=3.38
# Changing to logg=3.50 for T= 26528 logg=3.36
# Changing to logg=3.50 for T= 26272 logg=3.34
# Changing to logg=3.50 for T= 26010 logg=3.32
# Changing to logg=3.00 for T= 21762 logg=2.99
# Changing to logg=3.00 for T= 21633 logg=2.98
# Changing to logg=3.00 for T= 21504 logg=2.97
# Changing to logg=3.00 for T= 21375 logg=2.96
# Changing to logg=3.00 for T= 21247 logg=2.95
# Changing to logg=3.00 for T= 21119 logg=2.94
# Changing to logg=3.00 for T= 20992 logg=2.92
# Changing to logg=3.00 for T= 20865 logg=2.91
# Changing to logg=3.00 for T= 20738 logg=2.90
# Changing to logg=3.00 for T= 20612 logg=2.89
# Changing to logg=3.00 for T= 20486 logg=2.88
# Changing to logg=3.00 for T= 20360 logg=2.87
# Changing to logg=3.00 for T= 20235 logg=2.86
# Changing to logg=3.00 for T= 20110 logg=2.85
# Changing to logg=3.00 for T= 19986 logg=2.83
# Changing to logg=3.00 for T= 19862 logg=2.82
# Changing to logg=3.00 for T= 19738 logg=2.81
# Changing to logg=3.00 for T= 19615 logg=2.80
# Changing to logg=3.00 for T= 19493 logg=2.79
# Changing to logg=3.00 for T= 19372 logg=2.78
# Changing to logg=3.00 for T= 19251 logg=2.76
# Changing to logg=3.00 for T= 19131 logg=2.75
# Changing to logg=3.00 for T= 19012 logg=2.74
# Changing to logg=2.50 for T= 16675 logg=2.49
# Changing to logg=2.50 for T= 16571 logg=2.48
# Changing to logg=2.50 for T= 16468 logg=2.47
# Changing to logg=2.50 for T= 16366 logg=2.45
# Changing to logg=2.50 for T= 16264 logg=2.44
# Changing to logg=2.50 for T= 16163 logg=2.43
# Changing to logg=2.50 for T= 16062 logg=2.42
# Changing to logg=2.50 for T= 15981 logg=2.41
# Changing to logg=2.50 for T= 15900 logg=2.40
# Changing to logg=2.50 for T= 15820 logg=2.39
# Changing to logg=2.50 for T= 15740 logg=2.38
# Changing to logg=2.50 for T= 15660 logg=2.37
# Changing to logg=2.50 for T= 15581 logg=2.36
# Changing to logg=2.50 for T= 15502 logg=2.35
# Changing to logg=2.50 for T= 15424 logg=2.34
# Changing to logg=2.50 for T= 15347 logg=2.33
# Changing to logg=2.50 for T= 15270 logg=2.32
# Changing to logg=2.50 for T= 15193 logg=2.31
# Changing to logg=2.50 for T= 15118 logg=2.30
# Changing to logg=2.50 for T= 15042 logg=2.29
# Changing to logg=2.50 for T= 14525 logg=2.22
# Changing to logg=2.50 for T= 14074 logg=2.15
# Changing to logg=2.50 for T= 13608 logg=2.07
# Changing to logg=2.50 for T= 13139 logg=2.00
# Changing to logg=2.50 for T= 12676 logg=1.93
# Changing to logg=2.50 for T= 12223 logg=1.86
# Changing to logg=2.50 for T= 11780 logg=1.79
# Changing to logg=2.00 for T= 11350 logg=1.72
# Changing to logg=2.00 for T= 10934 logg=1.66
# Changing to logg=2.00 for T= 10531 logg=1.59
# Changing to logg=2.00 for T= 10140 logg=1.52
# Changing to logg=2.00 for T=  9762 logg=1.45
# Changing to logg=2.00 for T=  9396 logg=1.38
# Changing to logg=2.00 for T=  9043 logg=1.31
# Changing to logg=1.50 for T=  8703 logg=1.25
# Changing to logg=1.50 for T=  8375 logg=1.18
# Isochrone generation took 41.852562 s.
# Making photometry for isochrone: log(t) = 7.00  AKs = 0.50  dist = 4000
#      Starting at:  2019-11-06 14:33:02.785210   Usually takes ~5 minutes
# Starting filter: ubv,V   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.106 Msun  T =  3328 K  m_ubv_V = 28.14
# M =   6.758 Msun  T = 22100 K  m_ubv_V = 16.20
# M =  18.563 Msun  T = 21633 K  m_ubv_V = 11.71
# Starting filter: ubv,I   Elapsed time: 5.87 seconds
# Starting synthetic photometry
# M =   0.106 Msun  T =  3328 K  m_ubv_I = 23.66
# M =   6.758 Msun  T = 22100 K  m_ubv_I = 14.43
# M =  18.563 Msun  T = 21633 K  m_ubv_I = 9.92
# Starting filter: nirc2,J   Elapsed time: 11.36 seconds
# Starting synthetic photometry
# M =   0.106 Msun  T =  3328 K  m_nirc2_J = 21.71
# M =   6.758 Msun  T = 22100 K  m_nirc2_J = 13.60
# M =  18.563 Msun  T = 21633 K  m_nirc2_J = 9.10
# Starting filter: nirc2,Kp   Elapsed time: 15.89 seconds
# Starting synthetic photometry
# M =   0.106 Msun  T =  3328 K  m_nirc2_Kp = 20.18
# M =   6.758 Msun  T = 22100 K  m_nirc2_Kp = 13.05
# M =  18.563 Msun  T = 21633 K  m_nirc2_Kp = 8.55
# Starting filter: jwst,F070W   Elapsed time: 22.38 seconds
# Starting synthetic photometry
# M =   0.106 Msun  T =  3328 K  m_jwst_F070W = 25.60
# M =   6.758 Msun  T = 22100 K  m_jwst_F070W = 15.22
# M =  18.563 Msun  T = 21633 K  m_jwst_F070W = 10.72
# Starting filter: wfc3,ir,f153m   Elapsed time: 30.27 seconds
# Starting synthetic photometry
# M =   0.106 Msun  T =  3328 K  m_hst_f153m = 20.89
# M =   6.758 Msun  T = 22100 K  m_hst_f153m = 13.29
# M =  18.563 Msun  T = 21633 K  m_hst_f153m = 8.80
# Starting filter: jwst,F277W   Elapsed time: 38.29 seconds
# Starting synthetic photometry
# M =   0.106 Msun  T =  3328 K  m_jwst_F277W = 19.97
# M =   6.758 Msun  T = 22100 K  m_jwst_F277W = 12.91
# M =  18.563 Msun  T = 21633 K  m_jwst_F277W = 8.41
# Starting filter: jwst,F480M   Elapsed time: 48.00 seconds
# Starting synthetic photometry
# M =   0.106 Msun  T =  3328 K  m_jwst_F480M = 19.54
# M =   6.758 Msun  T = 22100 K  m_jwst_F480M = 12.92
# M =  18.563 Msun  T = 21633 K  m_jwst_F480M = 8.42
#       Time taken: 56.40 seconds
# Isochrone generation took 65.464052 s.
# Making photometry for isochrone: log(t) = 9.00  AKs = 0.50  dist = 4000
#      Starting at:  2019-11-06 14:35:04.689767   Usually takes ~5 minutes
# Starting filter: ubv,V   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.106 Msun  T =  2909 K  m_ubv_V = 33.21
# M =   2.038 Msun  T =  7816 K  m_ubv_V = 18.11
# M =   2.071 Msun  T =  4749 K  m_ubv_V = 17.94
# M =   2.287 Msun  T =  3677 K  m_ubv_V = 15.70
# M =   2.287 Msun  T =  3478 K  m_ubv_V = 15.95
# M =   2.288 Msun  T =  3188 K  m_ubv_V = 17.73
# M =   2.288 Msun  T = 134813 K  m_ubv_V = 20.21
# Starting filter: ubv,I   Elapsed time: 13.98 seconds
# Starting synthetic photometry
# M =   0.106 Msun  T =  2909 K  m_ubv_I = 26.56
# M =   2.038 Msun  T =  7816 K  m_ubv_I = 15.80
# M =   2.071 Msun  T =  4749 K  m_ubv_I = 14.72
# M =   2.287 Msun  T =  3677 K  m_ubv_I = 11.47
# M =   2.287 Msun  T =  3478 K  m_ubv_I = 11.04
# M =   2.288 Msun  T =  3188 K  m_ubv_I = 10.87
# M =   2.288 Msun  T = 134813 K  m_ubv_I = 18.60
# Starting filter: nirc2,J   Elapsed time: 27.90 seconds
# Starting synthetic photometry
# M =   0.106 Msun  T =  2909 K  m_nirc2_J = 24.32
# M =   2.038 Msun  T =  7816 K  m_nirc2_J = 14.67
# M =   2.071 Msun  T =  4749 K  m_nirc2_J = 13.11
# M =   2.287 Msun  T =  3677 K  m_nirc2_J = 9.51
# M =   2.287 Msun  T =  3478 K  m_nirc2_J = 8.94
# M =   2.288 Msun  T =  3188 K  m_nirc2_J = 8.30
# M =   2.288 Msun  T = 134813 K  m_nirc2_J = 17.88
# Starting filter: nirc2,Kp   Elapsed time: 39.57 seconds
# Starting synthetic photometry
# M =   0.106 Msun  T =  2909 K  m_nirc2_Kp = 22.90
# M =   2.038 Msun  T =  7816 K  m_nirc2_Kp = 13.88
# M =   2.071 Msun  T =  4749 K  m_nirc2_Kp = 11.80
# M =   2.287 Msun  T =  3677 K  m_nirc2_Kp = 7.72
# M =   2.287 Msun  T =  3478 K  m_nirc2_Kp = 7.05
# M =   2.288 Msun  T =  3188 K  m_nirc2_Kp = 6.31
# M =   2.288 Msun  T = 134813 K  m_nirc2_Kp = 17.41
# Starting filter: jwst,F070W   Elapsed time: 53.38 seconds
# Starting synthetic photometry
# M =   0.106 Msun  T =  2909 K  m_jwst_F070W = 29.42
# M =   2.038 Msun  T =  7816 K  m_jwst_F070W = 16.84
# M =   2.071 Msun  T =  4749 K  m_jwst_F070W = 16.09
# M =   2.287 Msun  T =  3677 K  m_jwst_F070W = 13.30
# M =   2.287 Msun  T =  3478 K  m_jwst_F070W = 13.20
# M =   2.288 Msun  T =  3188 K  m_jwst_F070W = 13.84
# M =   2.288 Msun  T = 134813 K  m_jwst_F070W = 19.31
# Starting filter: wfc3,ir,f153m   Elapsed time: 71.50 seconds
# Starting synthetic photometry
# M =   0.106 Msun  T =  2909 K  m_hst_f153m = 23.64
# M =   2.038 Msun  T =  7816 K  m_hst_f153m = 14.24
# M =   2.071 Msun  T =  4749 K  m_hst_f153m = 12.31
# M =   2.287 Msun  T =  3677 K  m_hst_f153m = 8.45
# M =   2.287 Msun  T =  3478 K  m_hst_f153m = 7.84
# M =   2.288 Msun  T =  3188 K  m_hst_f153m = 7.16
# M =   2.288 Msun  T = 134813 K  m_hst_f153m = 17.61
# Starting filter: jwst,F277W   Elapsed time: 89.51 seconds
# Starting synthetic photometry
# M =   0.106 Msun  T =  2909 K  m_jwst_F277W = 22.79
# M =   2.038 Msun  T =  7816 K  m_jwst_F277W = 13.70
# M =   2.071 Msun  T =  4749 K  m_jwst_F277W = 11.62
# M =   2.287 Msun  T =  3677 K  m_jwst_F277W = 7.62
# M =   2.287 Msun  T =  3478 K  m_jwst_F277W = 7.00
# M =   2.288 Msun  T =  3188 K  m_jwst_F277W = 6.35
# M =   2.288 Msun  T = 134813 K  m_jwst_F277W = 18.45
# Starting filter: jwst,F480M   Elapsed time: 112.00 seconds
# Starting synthetic photometry
# M =   0.106 Msun  T =  2909 K  m_jwst_F480M = 22.26
# M =   2.038 Msun  T =  7816 K  m_jwst_F480M = 13.64
# M =   2.071 Msun  T =  4749 K  m_jwst_F480M = 11.62
# M =   2.287 Msun  T =  3677 K  m_jwst_F480M = 7.53
# M =   2.287 Msun  T =  3478 K  m_jwst_F480M = 6.85
# M =   2.288 Msun  T =  3188 K  m_jwst_F480M = 6.06
# M =   2.288 Msun  T = 134813 K  m_jwst_F480M = 24.81
#       Time taken: 133.29 seconds
# Isochrone generation took 80.789808 s.
# Making photometry for isochrone: log(t) = 9.00  AKs = 0.50  dist = 4000
#      Starting at:  2019-11-06 14:38:38.866130   Usually takes ~5 minutes
# Starting filter: ubv,V   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.108 Msun  T =  3209 K  m_ubv_V = 30.92
# M =   1.833 Msun  T =  8248 K  m_ubv_V = 18.39
# M =   1.888 Msun  T =  4313 K  m_ubv_V = 15.98
# M =   2.066 Msun  T =  4237 K  m_ubv_V = 15.57
# M =   2.067 Msun  T =  3619 K  m_ubv_V = 14.85
# M =   2.068 Msun  T =  3576 K  m_ubv_V = 14.93
# M =   2.069 Msun  T = 46104 K  m_ubv_V = 16.63
# Starting filter: ubv,I   Elapsed time: 15.63 seconds
# Starting synthetic photometry
# M =   0.108 Msun  T =  3209 K  m_ubv_I = 26.22
# M =   1.833 Msun  T =  8248 K  m_ubv_I = 16.15
# M =   1.888 Msun  T =  4313 K  m_ubv_I = 12.54
# M =   2.066 Msun  T =  4237 K  m_ubv_I = 12.07
# M =   2.067 Msun  T =  3619 K  m_ubv_I = 10.68
# M =   2.068 Msun  T =  3576 K  m_ubv_I = 10.66
# M =   2.069 Msun  T = 46104 K  m_ubv_I = 14.94
# Starting filter: nirc2,J   Elapsed time: 30.84 seconds
# Starting synthetic photometry
# M =   0.108 Msun  T =  3209 K  m_nirc2_J = 24.20
# M =   1.833 Msun  T =  8248 K  m_nirc2_J = 15.05
# M =   1.888 Msun  T =  4313 K  m_nirc2_J = 10.81
# M =   2.066 Msun  T =  4237 K  m_nirc2_J = 10.32
# M =   2.067 Msun  T =  3619 K  m_nirc2_J = 8.68
# M =   2.068 Msun  T =  3576 K  m_nirc2_J = 8.65
# M =   2.069 Msun  T = 46104 K  m_nirc2_J = 14.18
# Starting filter: nirc2,Kp   Elapsed time: 44.16 seconds
# Starting synthetic photometry
# M =   0.108 Msun  T =  3209 K  m_nirc2_Kp = 22.72
# M =   1.833 Msun  T =  8248 K  m_nirc2_Kp = 14.29
# M =   1.888 Msun  T =  4313 K  m_nirc2_Kp = 9.31
# M =   2.066 Msun  T =  4237 K  m_nirc2_Kp = 8.79
# M =   2.067 Msun  T =  3619 K  m_nirc2_Kp = 6.82
# M =   2.068 Msun  T =  3576 K  m_nirc2_Kp = 6.77
# M =   2.069 Msun  T = 46104 K  m_nirc2_Kp = 13.68
# Starting filter: jwst,F070W   Elapsed time: 60.13 seconds
# Starting synthetic photometry
# M =   0.108 Msun  T =  3209 K  m_jwst_F070W = 28.26
# M =   1.833 Msun  T =  8248 K  m_jwst_F070W = 17.18
# M =   1.888 Msun  T =  4313 K  m_jwst_F070W = 14.01
# M =   2.066 Msun  T =  4237 K  m_jwst_F070W = 13.57
# M =   2.067 Msun  T =  3619 K  m_jwst_F070W = 12.47
# M =   2.068 Msun  T =  3576 K  m_jwst_F070W = 12.50
# M =   2.069 Msun  T = 46104 K  m_jwst_F070W = 15.68
# Starting filter: wfc3,ir,f153m   Elapsed time: 82.18 seconds
# Starting synthetic photometry
# M =   0.108 Msun  T =  3209 K  m_hst_f153m = 23.38
# M =   1.833 Msun  T =  8248 K  m_hst_f153m = 14.64
# M =   1.888 Msun  T =  4313 K  m_hst_f153m = 9.89
# M =   2.066 Msun  T =  4237 K  m_hst_f153m = 9.38
# M =   2.067 Msun  T =  3619 K  m_hst_f153m = 7.57
# M =   2.068 Msun  T =  3576 K  m_hst_f153m = 7.53
# M =   2.069 Msun  T = 46104 K  m_hst_f153m = 13.90
# Starting filter: jwst,F277W   Elapsed time: 103.41 seconds
# Starting synthetic photometry
# M =   0.108 Msun  T =  3209 K  m_jwst_F277W = 22.50
# M =   1.833 Msun  T =  8248 K  m_jwst_F277W = 14.11
# M =   1.888 Msun  T =  4313 K  m_jwst_F277W = 9.14
# M =   2.066 Msun  T =  4237 K  m_jwst_F277W = 8.62
# M =   2.067 Msun  T =  3619 K  m_jwst_F277W = 6.75
# M =   2.068 Msun  T =  3576 K  m_jwst_F277W = 6.71
# M =   2.069 Msun  T = 46104 K  m_jwst_F277W = 14.70
# Starting filter: jwst,F480M   Elapsed time: 128.61 seconds
# Starting synthetic photometry
# M =   0.108 Msun  T =  3209 K  m_jwst_F480M = 22.05
# M =   1.833 Msun  T =  8248 K  m_jwst_F480M = 14.05
# M =   1.888 Msun  T =  4313 K  m_jwst_F480M = 9.13
# M =   2.066 Msun  T =  4237 K  m_jwst_F480M = 8.61
# M =   2.067 Msun  T =  3619 K  m_jwst_F480M = 6.62
# M =   2.068 Msun  T =  3576 K  m_jwst_F480M = 6.56
# M =   2.069 Msun  T = 46104 K  m_jwst_F480M = 21.07
#       Time taken: 150.38 seconds

# %%
# Make figure
py.figure(figsize(30,20))
py.subplot(231)
py.plot(iso_sol_young['m_ubv_V'] - iso_sol_young['m_ubv_I'],
       iso_sol_young['m_ubv_V'], 'b-', label='10 Myr, [Z] = 0')
py.plot(iso_smc_young['m_ubv_V'] - iso_smc_young['m_ubv_I'],
       iso_smc_young['m_ubv_V'], 'b--', label='10 Myr, [Z] = -0.65')
py.plot(iso_sol_old['m_ubv_V'] - iso_sol_old['m_ubv_I'],
       iso_sol_old['m_ubv_V'], 'r-', label='1 Gyr, [Z] = 0')
py.plot(iso_smc_old['m_ubv_V'] - iso_smc_old['m_ubv_I'],
       iso_smc_old['m_ubv_V'], 'r--', label='1 Gyr, [Z] = -0.65')
py.xlabel('V - I', fontsize=24)
py.ylabel('V', fontsize=24)
py.tick_params(axis='both', labelsize=20)
py.legend(loc=1, fontsize=20)
py.gca().invert_yaxis()
py.subplot(232)
py.plot(iso_sol_young['m_ubv_V'] - iso_sol_young['m_nirc2_Kp'],
       iso_sol_young['m_ubv_V'], 'b-', label='10 Myr, [Z] = 0')
py.plot(iso_smc_young['m_ubv_V'] - iso_smc_young['m_nirc2_Kp'],
       iso_smc_young['m_ubv_V'], 'b--', label='10 Myr, [Z] = -065')
py.plot(iso_sol_old['m_ubv_V'] - iso_sol_old['m_nirc2_Kp'],
       iso_sol_old['m_ubv_V'], 'r-', label='1 Gyr, [Z] = 0')
py.plot(iso_smc_old['m_ubv_V'] - iso_smc_old['m_nirc2_Kp'],
       iso_smc_old['m_ubv_V'], 'r--', label='1 Gyr, [Z] = -0.65')
py.xlabel('V - Kp', fontsize=24)
py.ylabel('V', fontsize=24)
py.tick_params(axis='both', labelsize=20)
py.legend(fontsize=20, loc=1)
py.gca().invert_yaxis()
py.subplot(233)
py.plot(iso_sol_young['m_ubv_I'] - iso_sol_young['m_nirc2_Kp'],
       iso_sol_young['m_ubv_I'], 'b-', label='10 Myr, [Z] = 0')
py.plot(iso_smc_young['m_ubv_I'] - iso_smc_young['m_nirc2_Kp'],
       iso_smc_young['m_ubv_I'], 'b--', label='10 Myr, [Z] = -0.65')
py.plot(iso_sol_old['m_ubv_I'] - iso_sol_old['m_nirc2_Kp'],
       iso_sol_old['m_ubv_I'], 'r-', label='1 Gyr, [Z] = 0')
py.plot(iso_smc_old['m_ubv_I'] - iso_smc_old['m_nirc2_Kp'],
       iso_smc_old['m_ubv_I'], 'r--', label='1 Gyr, [Z] = -0.65')
py.xlabel('I - Kp', fontsize=24)
py.ylabel('I', fontsize=24)
py.tick_params(axis='both', labelsize=20)
py.legend(fontsize=20)
py.gca().invert_yaxis()
py.subplot(234)
py.plot(iso_sol_young['m_nirc2_J'] - iso_sol_young['m_nirc2_Kp'],
       iso_sol_young['m_nirc2_J'], 'b-', label='10 Myr, [Z] = 0')
py.plot(iso_smc_young['m_nirc2_J'] - iso_smc_young['m_nirc2_Kp'],
       iso_smc_young['m_nirc2_J'], 'b--', label='10 Myr, [Z] = -0.65')
py.plot(iso_sol_old['m_nirc2_J'] - iso_sol_old['m_nirc2_Kp'],
       iso_sol_old['m_nirc2_J'], 'r-', label='1 Gyr, [Z] = 0')
py.plot(iso_smc_old['m_nirc2_J'] - iso_smc_old['m_nirc2_Kp'],
       iso_smc_old['m_nirc2_J'], 'r--', label='1 Gyr, [Z] = -0.65')
py.xlabel('J - Kp', fontsize=24)
py.ylabel('J', fontsize=24)
py.tick_params(axis='both', labelsize=20)
py.legend(fontsize=20)
py.gca().invert_yaxis()
py.subplot(235)
py.plot(iso_sol_young['m_jwst_F070W'] - iso_sol_young['m_jwst_F480M'],
       iso_sol_young['m_jwst_F070W'], 'b-', label='10 Myr, [Z] = 0')
py.plot(iso_smc_young['m_jwst_F070W'] - iso_smc_young['m_jwst_F480M'],
       iso_smc_young['m_jwst_F070W'], 'b--', label='10 Myr, [Z] = -0.65')
py.plot(iso_sol_old['m_jwst_F070W'] - iso_sol_old['m_jwst_F480M'],
       iso_sol_old['m_jwst_F070W'], 'r-', label='1 Gyr, [Z] = 0')
py.plot(iso_smc_old['m_jwst_F070W'] - iso_smc_old['m_jwst_F480M'],
       iso_smc_old['m_jwst_F070W'], 'r--', label='1 Gyr, [Z] = -0.65')
py.xlabel('JWST F070W - F480M', fontsize=24)
py.ylabel('JWST F070W', fontsize=24)
py.tick_params(axis='both', labelsize=20)
py.legend(fontsize=20)
py.gca().invert_yaxis()
py.subplot(236)
py.plot(iso_sol_young['m_hst_f153m'] - iso_sol_young['m_jwst_F480M'],
       iso_sol_young['m_hst_f153m'], 'b-', label='10 Myr, [Z] = 0')
py.plot(iso_smc_young['m_hst_f153m'] - iso_smc_young['m_jwst_F480M'],
       iso_smc_young['m_hst_f153m'], 'b--', label='10 Myr, [Z] = -0.65')
py.plot(iso_sol_old['m_hst_f153m'] - iso_sol_old['m_jwst_F480M'],
       iso_sol_old['m_hst_f153m'], 'r-', label='1 Gyr, [Z] = 0')
py.plot(iso_smc_old['m_hst_f153m'] - iso_smc_old['m_jwst_F480M'],
       iso_smc_old['m_hst_f153m'], 'r--', label='1 Gyr, [Z] = -0.65')
py.xlabel('HST F153M - JWST F480M', fontsize=24)
py.ylabel('HST F153M', fontsize=24)
py.tick_params(axis='both', labelsize=20)
py.legend(fontsize=20, loc=3)
py.gca().invert_yaxis()
py.savefig('iso_cmd.pdf', format='pdf')
